# %% [markdown]
# Assumption: Y-> linerly dependent to X(i)

# %% [markdown]
# "SKLEARN" - "NUMPY"

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35]]
y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)

# %%
x
# Out:
# array([[ 0,  1],
#        [ 5,  1],
#        [15,  2],
#        [25,  5],
#        [35, 11],
#        [45, 15],
#        [55, 34],
#        [60, 35]])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_new = model.predict(x)

# %%
model.coef_, model.intercept_
# Out:
# (array([0.44706965, 0.25502548]), 5.5225792751981935)

# %%
cost_cal(y_new, y)
# Out:
# 12.780935907417893

# %%
r_sq = model.score(x, y)

# %%
r_sq
# Out:
# 0.8615939258756776

# %%
y_pred = model.predict(x)

# %%
y_pred
# Out:
# array([ 5.77760476,  8.012953  , 12.73867497, 17.9744479 , 23.97529728,
#        29.4660957 , 38.78227633, 41.27265006])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %% [markdown]
# "SELF"

# %%
x
# Out:
# array([[ 0,  1],
#        [ 5,  1],
#        [15,  2],
#        [25,  5],
#        [35, 11],
#        [45, 15],
#        [55, 34],
#        [60, 35]])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %% [markdown]
# Steps:
# 1. Matrix evaluation
# 2. Cost function
# 3. Gradient descent

# %% [markdown]
# Matrix evaluation
#
# Output = Input * Weights

# %%
l = []
for i,e in enumerate(x):
    l.append(np.insert(e, 0, 1))

# %%
x_aug = np.array(l)

# %%
x_aug
# Out:
# array([[ 1,  0,  1],
#        [ 1,  5,  1],
#        [ 1, 15,  2],
#        [ 1, 25,  5],
#        [ 1, 35, 11],
#        [ 1, 45, 15],
#        [ 1, 55, 34],
#        [ 1, 60, 35]])

# %%
x_aug.shape
# Out:
# (8, 3)

# %%
beta = np.random.rand(3,1)

# %%
beta.shape
# Out:
# (3, 1)

# %%
np.matmul(x_aug,beta)
# Out:
# array([[ 1.19110121],
#        [ 2.35973099],
#        [ 5.23363395],
#        [ 9.18082372],
#        [14.73794369],
#        [19.22177686],
#        [31.75526107],
#        [33.46053425]])

# %%
def mat_evaluation(inp,weights):
    ans = np.matmul(inp, weights)
    return ans

# %%
mat_eva = mat_evaluation(x_aug,beta)

# %%
# Out:
# array([1.19110121])

# %% [markdown]
# Cost

# %%
m = len(y)

# %%
s = 0
for i in range(m):
    s = s + ((eva[i] - y[i])**2)
ans = s/(2*m)

# %%
ans
# Out:
# array([43.23914013])

# %%
def cost_cal(mat_eva, y):
    m = len(y)
    s = 0
    for i in range(m):
        s = s + ((mat_eva[i] - y[i])**2)
    ans = s/(2*m)
    return (ans)

# %%
c = cost_cal(mat_eva, y)

# %%
c
# Out:
# array([43.23914013])

# %% [markdown]
# Gradient Descent

# %%
alpha = 0.001

# %%
j = 1

# %%
m = len(y)

# %%
s = 0
for i in range(m):
    s = s + (((mat_eva[i] - y[i]))*x_aug[i][j])
ans = alpha*(1/m)*(s)

# %%
def gradient_descent_bj(mat_eva, y, x_aug, j):
    alpha = 0.001
    m = len(y)
    s = 0
    for i in range(m):
        s = s + (((mat_eva[i] - y[i]))*x_aug[i][j])
    ans = alpha*(1/m)*(s)
    return (ans)

# %%
gradient_descent_bj(mat_eva, y, x_aug, 1)
# Out:
# array([-0.25002461])

# %% [markdown]
# Implementation

# %%
x
# Out:
# array([[ 0,  1],
#        [ 5,  1],
#        [15,  2],
#        [25,  5],
#        [35, 11],
#        [45, 15],
#        [55, 34],
#        [60, 35]])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %%
x_aug
# Out:
# array([[ 1,  0,  1],
#        [ 1,  5,  1],
#        [ 1, 15,  2],
#        [ 1, 25,  5],
#        [ 1, 35, 11],
#        [ 1, 45, 15],
#        [ 1, 55, 34],
#        [ 1, 60, 35]])

# %%
beta = np.random.rand(3,1)
beta
# Out:
# array([[0.71919416],
#        [0.15833675],
#        [0.43642048]])

# %%
x
# Out:
# array([[ 0,  1],
#        [ 5,  1],
#        [15,  2],
#        [25,  5],
#        [35, 11],
#        [45, 15],
#        [55, 34],
#        [60, 35]])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
# Out:
# /Users/Rohan/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Rohan/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x
# Out:
# array([[-1.42413799, -0.90517714],
#        [-1.18678166, -0.90517714],
#        [-0.71206899, -0.82974572],
#        [-0.23735633, -0.60345143],
#        [ 0.23735633, -0.15086286],
#        [ 0.71206899,  0.15086286],
#        [ 1.18678166,  1.58406   ],
#        [ 1.42413799,  1.65949143]])

# %%
l = []
for i,e in enumerate(x):
    l.append(np.insert(e, 0, 1))
x_aug = np.array(l)
    
epoch = 3000
beta = np.random.rand(len(x[0])+1,1)

for ep in range(epoch):
    print("Epoch:", ep)
#     print("Beta:", beta)
    y_hat = mat_evaluation(x_aug, beta)
#     print("mat_eva:", y_hat)
    c = cost_cal(y_hat, y)
    print("Cost:", c)

    for j, b in enumerate(beta):
        beta[j]= beta[j] - gradient_descent_bj(y_hat, y, x_aug, j)
# Out:
# Epoch: 0
# Cost: [320.44202721]
# Epoch: 1
# Cost: [319.70276944]
# Epoch: 2
# Cost: [318.96547356]
# Epoch: 3
# Cost: [318.23013379]
# Epoch: 4
# Cost: [317.49674435]
# Epoch: 5
# Cost: [316.7652995]
# Epoch: 6
# Cost: [316.03579352]
# Epoch: 7
# Cost: [315.30822067]
# Epoch: 8
# Cost: [314.58257529]
# Epoch: 9
# Cost: [313.85885168]
# Epoch: 10
# Cost: [313.13704419]
# Epoch: 11
# Cost: [312.41714719]
# Epoch: 12
# Cost: [311.69915505]
# Epoch: 13
# Cost: [310.98306218]
# Epoch: 14
# Cost: [310.26886299]
# Epoch: 15
# Cost: [309.55655191]
# Epoch: 16
# Cost: [308.84612339]
# Epoch: 17
# Cost: [308.13757192]
# Epoch: 18
# Cost: [307.43089196]
# Epoch: 19
# Cost: [306.72607804]
# Epoch: 20
# Cost: [306.02312468]
# Epoch: 21
# Cost: [305.32202641]
# Epoch: 22
# Cost: [304.62277779]
# Epoch: 23
# Cost: [303.92537341]
# Epoch: 24
# Cost: [303.22980785]
# Epoch: 25
# Cost: [302.53607573]
# Epoch: 26
# Cost: [301.84417168]
# Epoch: 27
# Cost: [301.15409033]
# Epoch: 28
# ...

# %%
beta
# Out:
# array([[21.16356703],
#        [ 6.6639869 ],
#        [ 6.09808353]])
